# %% [markdown]
# # Load ED 2015 SAS data
#
# Unzip `ed2015-sas.sas7bdat.zip` and load the `.sas7bdat` file into a pandas DataFrame.

# %%
import zipfile
from pathlib import Path

import pandas as pd
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [1], in <cell line: 4>()
#       1 import zipfile
#       2 from pathlib import Path
# ----> 4 import pandas as pd
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/__init__.py:11, in <module>
#       9 for _dependency in _hard_dependencies:
#      10     try:
# ---> 11         __import__(_dependency)
#      12     except ImportError as _e:
#      13         _missing_dependencies.append(f"{_dependency}: {_e}")
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/numpy/__init__.py:148, in <module>
#     145 __deprecated_attrs__ = {}
#     147 # Allow distributors to run custom init code
# --> 148 from . import _distributor_init
#     150 from . import core
#     151 from .core import *
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/numpy/_distributor_init.py:13, in <module>
# ...

# %%
data_dir = Path(".").resolve()  # notebook directory when run from med_proj/data
zip_path = data_dir / "ed2015-sas.sas7bdat.zip"

with zipfile.ZipFile(zip_path, "r") as zf:
    zf.extractall(path=data_dir)

sas_path = data_dir / "ed2015-sas.sas7bdat"
df = pd.read_sas(sas_path)

# %%
df.shape

# %%
df.head()
